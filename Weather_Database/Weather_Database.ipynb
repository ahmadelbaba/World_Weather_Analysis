# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | dawlatabad
# Processing Record 4 of Set 1 | novikovo
# Processing Record 5 of Set 1 | esperance
# Processing Record 6 of Set 1 | kahului
# Processing Record 7 of Set 1 | thompson
# Processing Record 8 of Set 1 | vila franca do campo
# Processing Record 9 of Set 1 | upernavik
# Processing Record 10 of Set 1 | tiarei
# Processing Record 11 of Set 1 | mumbwa
# Processing Record 12 of Set 1 | praia da vitoria
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | polonnaruwa
# Processing Record 15 of Set 1 | alice springs
# Processing Record 16 of Set 1 | hithadhoo
# Processing Record 17 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 1 | puerto baquerizo moreno
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | ushibuka
# Processing Record 21 of Set 1 | georgetown
# Processing Record 22 of Set 1 | norman wells
# Processing Record 23 of Set 1 | faanui
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | addi ugri
# City not found. Skipping...
# Processing Record 29 of Set 1 | clyde river
# Processing Record 30 of Set 1 | san patricio
# Processing Record 31 of Set 1 | grand gaube
# Processing Record 32 of Set 1 | aswan
# Processing Record 33 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | east london
# Processing Record 36 of Set 1 | margate
# Processing Record 37 of Set 1 | katsuura
# Processing Record 38 of Set 1 | tilichiki
# Processing Record 39 of Set 1 | homer
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 42 of Set 1 | andenes
# Processing Record 43 of Set 1 | la paz centro
# Processing Record 44 of Set 1 | raudeberg
# Processing Record 45 of Set 1 | linchuan
# City not found. Skipping...
# Processing Record 46 of Set 1 | luderitz
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | nueva italia
# Processing Record 49 of Set 1 | chokurdakh
# Processing Record 50 of Set 1 | salmas
# Processing Record 1 of Set 2 | zhigansk
# Processing Record 2 of Set 2 | rawson
# Processing Record 3 of Set 2 | asau
# Processing Record 4 of Set 2 | hibbing
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | kapaa
# Processing Record 7 of Set 2 | juba
# Processing Record 8 of Set 2 | berlevag
# Processing Record 9 of Set 2 | derzhavinsk
# Processing Record 10 of Set 2 | ormara
# Processing Record 11 of Set 2 | aklavik
# Processing Record 12 of Set 2 | airai
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | synevyr
# Processing Record 15 of Set 2 | sitka
# Processing Record 16 of Set 2 | chuy
# Processing Record 17 of Set 2 | merta
# Processing Record 18 of Set 2 | busselton
# Processing Record 19 of Set 2 | kaitangata
# Processing Record 20 of Set 2 | lahij
# Processing Record 21 of Set 2 | komsomolskiy
# Processing Record 22 of Set 2 | tiksi
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | lundazi
# Processing Record 25 of Set 2 | ulladulla
# Processing Record 26 of Set 2 | isetskoye
# Processing Record 27 of Set 2 | carnarvon
# Processing Record 28 of Set 2 | longyearbyen
# Processing Record 29 of Set 2 | mogadishu
# Processing Record 30 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 2 | broome
# Processing Record 32 of Set 2 | tasiilaq
# Processing Record 33 of Set 2 | cabo san lucas
# Processing Record 34 of Set 2 | souillac
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | jamestown
# Processing Record 37 of Set 2 | araouane
# Processing Record 38 of Set 2 | inhambane
# Processing Record 39 of Set 2 | westport
# Processing Record 40 of Set 2 | butaritari
# Processing Record 41 of Set 2 | wick
# Processing Record 42 of Set 2 | merrill
# Processing Record 43 of Set 2 | quang ngai
# Processing Record 44 of Set 2 | guerrero negro
# Processing Record 45 of Set 2 | sao filipe
# Processing Record 46 of Set 2 | taunggyi
# Processing Record 47 of Set 2 | saint george
# Processing Record 48 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 2 | cessnock
# Processing Record 50 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 1 of Set 3 | kathmandu
# Processing Record 2 of Set 3 | smolensk
# Processing Record 3 of Set 3 | isla mujeres
# Processing Record 4 of Set 3 | baran
# Processing Record 5 of Set 3 | xingyi
# Processing Record 6 of Set 3 | bethel
# Processing Record 7 of Set 3 | kargat
# Processing Record 8 of Set 3 | mataura
# Processing Record 9 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 3 | ola
# Processing Record 11 of Set 3 | quetzaltepec
# City not found. Skipping...
# Processing Record 12 of Set 3 | juneau
# Processing Record 13 of Set 3 | qaanaaq
# Processing Record 14 of Set 3 | provideniya
# Processing Record 15 of Set 3 | fortuna
# Processing Record 16 of Set 3 | kruisfontein
# Processing Record 17 of Set 3 | hobyo
# Processing Record 18 of Set 3 | cidreira
# Processing Record 19 of Set 3 | sorland
# Processing Record 20 of Set 3 | saskylakh
# Processing Record 21 of Set 3 | laguna
# Processing Record 22 of Set 3 | nikolskoye
# Processing Record 23 of Set 3 | flin flon
# Processing Record 24 of Set 3 | khatanga
# Processing Record 25 of Set 3 | tonj
# Processing Record 26 of Set 3 | klaksvik
# Processing Record 27 of Set 3 | kaeo
# Processing Record 28 of Set 3 | kantunilkin
# Processing Record 29 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 3 | mahebourg
# Processing Record 31 of Set 3 | balkhash
# Processing Record 32 of Set 3 | calvinia
# Processing Record 33 of Set 3 | lompoc
# Processing Record 34 of Set 3 | dunedin
# Processing Record 35 of Set 3 | codrington
# Processing Record 36 of Set 3 | ponta do sol
# Processing Record 37 of Set 3 | maceio
# Processing Record 38 of Set 3 | flinders
# Processing Record 39 of Set 3 | castro
# Processing Record 40 of Set 3 | lavrentiya
# Processing Record 41 of Set 3 | amapa
# Processing Record 42 of Set 3 | yibin
# Processing Record 43 of Set 3 | port alfred
# Processing Record 44 of Set 3 | egvekinot
# Processing Record 45 of Set 3 | port elizabeth
# Processing Record 46 of Set 3 | portland
# Processing Record 47 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 3 | aripuana
# Processing Record 49 of Set 3 | albanel
# Processing Record 50 of Set 3 | itaguai
# Processing Record 1 of Set 4 | thinadhoo
# Processing Record 2 of Set 4 | lerwick
# Processing Record 3 of Set 4 | kamaishi
# Processing Record 4 of Set 4 | ratnagiri
# Processing Record 5 of Set 4 | stavern
# Processing Record 6 of Set 4 | tuktoyaktuk
# Processing Record 7 of Set 4 | stornoway
# Processing Record 8 of Set 4 | camacha
# Processing Record 9 of Set 4 | bengkulu
# Processing Record 10 of Set 4 | kiruna
# Processing Record 11 of Set 4 | numan
# Processing Record 12 of Set 4 | emerald
# Processing Record 13 of Set 4 | tiznit
# Processing Record 14 of Set 4 | sulangan
# Processing Record 15 of Set 4 | port hardy
# Processing Record 16 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 4 | sur
# Processing Record 18 of Set 4 | cherskiy
# Processing Record 19 of Set 4 | saldanha
# Processing Record 20 of Set 4 | haines junction
# Processing Record 21 of Set 4 | mongu
# Processing Record 22 of Set 4 | vila velha
# Processing Record 23 of Set 4 | mao
# Processing Record 24 of Set 4 | vaitape
# Processing Record 25 of Set 4 | tolmin
# Processing Record 26 of Set 4 | saint-philippe
# Processing Record 27 of Set 4 | atuona
# Processing Record 28 of Set 4 | puerto escondido
# Processing Record 29 of Set 4 | xinqing
# Processing Record 30 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 4 | kobyzhcha
# Processing Record 32 of Set 4 | vao
# Processing Record 33 of Set 4 | kozhva
# Processing Record 34 of Set 4 | erenhot
# Processing Record 35 of Set 4 | jumla
# Processing Record 36 of Set 4 | fort madison
# Processing Record 37 of Set 4 | byumba
# Processing Record 38 of Set 4 | ilulissat
# Processing Record 39 of Set 4 | college
# Processing Record 40 of Set 4 | buariki
# City not found. Skipping...
# Processing Record 41 of Set 4 | geraldton
# Processing Record 42 of Set 4 | port hedland
# Processing Record 43 of Set 4 | winfield
# Processing Record 44 of Set 4 | severo-kurilsk
# Processing Record 45 of Set 4 | padang
# Processing Record 46 of Set 4 | karratha
# Processing Record 47 of Set 4 | adeje
# Processing Record 48 of Set 4 | terrace
# Processing Record 49 of Set 4 | pointe michel
# Processing Record 50 of Set 4 | kloulklubed
# Processing Record 1 of Set 5 | meulaboh
# Processing Record 2 of Set 5 | kargil
# Processing Record 3 of Set 5 | ovria
# Processing Record 4 of Set 5 | kerman
# Processing Record 5 of Set 5 | dikson
# Processing Record 6 of Set 5 | tempio pausania
# Processing Record 7 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 5 | torbay
# Processing Record 9 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 10 of Set 5 | touros
# Processing Record 11 of Set 5 | saginaw
# Processing Record 12 of Set 5 | kindersley
# Processing Record 13 of Set 5 | salinopolis
# Processing Record 14 of Set 5 | gilazi
# City not found. Skipping...
# Processing Record 15 of Set 5 | beringovskiy
# Processing Record 16 of Set 5 | viedma
# Processing Record 17 of Set 5 | la ronge
# Processing Record 18 of Set 5 | kodinsk
# Processing Record 19 of Set 5 | olafsvik
# Processing Record 20 of Set 5 | imeni zhelyabova
# Processing Record 21 of Set 5 | arraial do cabo
# Processing Record 22 of Set 5 | kattivakkam
# Processing Record 23 of Set 5 | tawang
# Processing Record 24 of Set 5 | nouadhibou
# Processing Record 25 of Set 5 | srednekolymsk
# Processing Record 26 of Set 5 | hamilton
# Processing Record 27 of Set 5 | arman
# Processing Record 28 of Set 5 | cavnic
# Processing Record 29 of Set 5 | hirara
# Processing Record 30 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 31 of Set 5 | road town
# Processing Record 32 of Set 5 | mwinilunga
# Processing Record 33 of Set 5 | beloha
# Processing Record 34 of Set 5 | stolin
# Processing Record 35 of Set 5 | cockburn town
# Processing Record 36 of Set 5 | jandaia do sul
# Processing Record 37 of Set 5 | bandarbeyla
# Processing Record 38 of Set 5 | ahipara
# Processing Record 39 of Set 5 | yellowknife
# Processing Record 40 of Set 5 | yar-sale
# Processing Record 41 of Set 5 | ozernovskiy
# Processing Record 42 of Set 5 | mumford
# Processing Record 43 of Set 5 | iguaba grande
# Processing Record 44 of Set 5 | falealupo
# City not found. Skipping...
# Processing Record 45 of Set 5 | vestmannaeyjar
# Processing Record 46 of Set 5 | statesboro
# Processing Record 47 of Set 5 | urumqi
# Processing Record 48 of Set 5 | olinda
# Processing Record 49 of Set 5 | nola
# Processing Record 50 of Set 5 | cape town
# Processing Record 1 of Set 6 | jais
# Processing Record 2 of Set 6 | matara
# Processing Record 3 of Set 6 | fairbanks
# Processing Record 4 of Set 6 | ballina
# Processing Record 5 of Set 6 | matagami
# Processing Record 6 of Set 6 | atar
# Processing Record 7 of Set 6 | tumaco
# Processing Record 8 of Set 6 | sisimiut
# Processing Record 9 of Set 6 | sola
# Processing Record 10 of Set 6 | magistralnyy
# Processing Record 11 of Set 6 | ostrovnoy
# Processing Record 12 of Set 6 | leningradskiy
# Processing Record 13 of Set 6 | shache
# Processing Record 14 of Set 6 | hasaki
# Processing Record 15 of Set 6 | sobolevo
# Processing Record 16 of Set 6 | hornepayne
# Processing Record 17 of Set 6 | namibe
# Processing Record 18 of Set 6 | pevek
# Processing Record 19 of Set 6 | tchaourou
# Processing Record 20 of Set 6 | bathsheba
# Processing Record 21 of Set 6 | port macquarie
# Processing Record 22 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 6 | damietta
# Processing Record 24 of Set 6 | togur
# Processing Record 25 of Set 6 | yaan
# Processing Record 26 of Set 6 | hokitika
# Processing Record 27 of Set 6 | mount gambier
# Processing Record 28 of Set 6 | weyburn
# Processing Record 29 of Set 6 | yerbogachen
# Processing Record 30 of Set 6 | carutapera
# Processing Record 31 of Set 6 | mar del plata
# Processing Record 32 of Set 6 | mapastepec
# Processing Record 33 of Set 6 | marquette
# Processing Record 34 of Set 6 | sandwick
# Processing Record 35 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 36 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 6 | kerki
# City not found. Skipping...
# Processing Record 38 of Set 6 | kodiak
# Processing Record 39 of Set 6 | chernyshevskiy
# Processing Record 40 of Set 6 | simao
# Processing Record 41 of Set 6 | zhaozhou
# Processing Record 42 of Set 6 | muncar
# Processing Record 43 of Set 6 | buchmany
# Processing Record 44 of Set 6 | osakarovka
# Processing Record 45 of Set 6 | coahuayana
# Processing Record 46 of Set 6 | victoria
# Processing Record 47 of Set 6 | sistranda
# Processing Record 48 of Set 6 | anzio
# Processing Record 49 of Set 6 | salekhard
# Processing Record 50 of Set 6 | badvel
# Processing Record 1 of Set 7 | chimore
# Processing Record 2 of Set 7 | tikapur
# Processing Record 3 of Set 7 | lata
# Processing Record 4 of Set 7 | duxbury
# Processing Record 5 of Set 7 | bossangoa
# Processing Record 6 of Set 7 | howard springs
# Processing Record 7 of Set 7 | sabla
# Processing Record 8 of Set 7 | almeria
# Processing Record 9 of Set 7 | kiboga
# Processing Record 10 of Set 7 | kiama
# Processing Record 11 of Set 7 | san ramon
# Processing Record 12 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 7 | sorong
# Processing Record 14 of Set 7 | umm kaddadah
# Processing Record 15 of Set 7 | auki
# Processing Record 16 of Set 7 | rio grande
# Processing Record 17 of Set 7 | virginia beach
# Processing Record 18 of Set 7 | saint-leu
# Processing Record 19 of Set 7 | nome
# Processing Record 20 of Set 7 | den helder
# Processing Record 21 of Set 7 | dupnica
# City not found. Skipping...
# Processing Record 22 of Set 7 | pitogo
# Processing Record 23 of Set 7 | rapid valley
# Processing Record 24 of Set 7 | naze
# Processing Record 25 of Set 7 | hun
# Processing Record 26 of Set 7 | muravlenko
# Processing Record 27 of Set 7 | vikhorevka
# Processing Record 28 of Set 7 | wajima
# Processing Record 29 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 30 of Set 7 | lebu
# Processing Record 31 of Set 7 | goundam
# Processing Record 32 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 7 | disna
# Processing Record 34 of Set 7 | lagoa
# Processing Record 35 of Set 7 | mecca
# Processing Record 36 of Set 7 | muroto
# Processing Record 37 of Set 7 | paso de carrasco
# Processing Record 38 of Set 7 | sychevka
# Processing Record 39 of Set 7 | kulhudhuffushi
# Processing Record 40 of Set 7 | princeton
# Processing Record 41 of Set 7 | viransehir
# Processing Record 42 of Set 7 | dakar
# Processing Record 43 of Set 7 | san quintin
# Processing Record 44 of Set 7 | bobrovka
# Processing Record 45 of Set 7 | san cristobal
# Processing Record 46 of Set 7 | crab hill
# City not found. Skipping...
# Processing Record 47 of Set 7 | goroka
# Processing Record 48 of Set 7 | alofi
# Processing Record 49 of Set 7 | palembang
# Processing Record 50 of Set 7 | necochea
# Processing Record 1 of Set 8 | acarau
# Processing Record 2 of Set 8 | svetlyy
# Processing Record 3 of Set 8 | nawabganj
# Processing Record 4 of Set 8 | canberra
# Processing Record 5 of Set 8 | murgab
# Processing Record 6 of Set 8 | kenora
# Processing Record 7 of Set 8 | sumbe
# Processing Record 8 of Set 8 | alamos
# Processing Record 9 of Set 8 | tuskegee
# Processing Record 10 of Set 8 | wasilla
# Processing Record 11 of Set 8 | arlit
# Processing Record 12 of Set 8 | los corrales de buelna
# Processing Record 13 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 8 | fort nelson
# Processing Record 15 of Set 8 | payakumbuh
# Processing Record 16 of Set 8 | mount isa
# Processing Record 17 of Set 8 | udachnyy
# Processing Record 18 of Set 8 | coquimbo
# Processing Record 19 of Set 8 | koslan
# Processing Record 20 of Set 8 | talnakh
# Processing Record 21 of Set 8 | luganville
# Processing Record 22 of Set 8 | petukhovo
# Processing Record 23 of Set 8 | isangel
# Processing Record 24 of Set 8 | uinskoye
# Processing Record 25 of Set 8 | narsaq
# Processing Record 26 of Set 8 | iqaluit
# Processing Record 27 of Set 8 | belmira
# Processing Record 28 of Set 8 | marathon
# Processing Record 29 of Set 8 | newport
# Processing Record 30 of Set 8 | alghero
# Processing Record 31 of Set 8 | santa marta
# Processing Record 32 of Set 8 | kinablangan
# Processing Record 33 of Set 8 | anadyr
# Processing Record 34 of Set 8 | waipawa
# Processing Record 35 of Set 8 | mascota
# Processing Record 36 of Set 8 | rimbey
# Processing Record 37 of Set 8 | pisco
# Processing Record 38 of Set 8 | caravelas
# Processing Record 39 of Set 8 | bintulu
# Processing Record 40 of Set 8 | katiola
# Processing Record 41 of Set 8 | marrakesh
# Processing Record 42 of Set 8 | los llanos de aridane
# Processing Record 43 of Set 8 | porto novo
# Processing Record 44 of Set 8 | coos bay
# Processing Record 45 of Set 8 | nakamura
# Processing Record 46 of Set 8 | ternate
# Processing Record 47 of Set 8 | astana
# Processing Record 48 of Set 8 | dingle
# Processing Record 49 of Set 8 | malanville
# Processing Record 50 of Set 8 | desert hot springs
# Processing Record 1 of Set 9 | kisszallas
# Processing Record 2 of Set 9 | bemidji
# Processing Record 3 of Set 9 | gold coast
# Processing Record 4 of Set 9 | ribeira grande
# Processing Record 5 of Set 9 | bima
# Processing Record 6 of Set 9 | pipirig
# Processing Record 7 of Set 9 | puerto padre
# Processing Record 8 of Set 9 | veraval
# Processing Record 9 of Set 9 | palmer
# Processing Record 10 of Set 9 | maltahohe
# Processing Record 11 of Set 9 | tolaga bay
# Processing Record 12 of Set 9 | poso
# Processing Record 13 of Set 9 | shingu
# Processing Record 14 of Set 9 | majene
# Processing Record 15 of Set 9 | santiago del estero
# Processing Record 16 of Set 9 | hofn
# Processing Record 17 of Set 9 | vardo
# Processing Record 18 of Set 9 | russell
# Processing Record 19 of Set 9 | agdam
# Processing Record 20 of Set 9 | harper
# Processing Record 21 of Set 9 | barcelona
# Processing Record 22 of Set 9 | savannah bight
# Processing Record 23 of Set 9 | tulle
# Processing Record 24 of Set 9 | ozark
# Processing Record 25 of Set 9 | mormugao
# Processing Record 26 of Set 9 | shenzhen
# Processing Record 27 of Set 9 | whitefish
# Processing Record 28 of Set 9 | ayni
# Processing Record 29 of Set 9 | maykain
# City not found. Skipping...
# Processing Record 30 of Set 9 | sahrak
# City not found. Skipping...
# Processing Record 31 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 32 of Set 9 | pagman
# City not found. Skipping...
# Processing Record 33 of Set 9 | pedernales
# Processing Record 34 of Set 9 | paita
# Processing Record 35 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 9 | coihaique
# Processing Record 37 of Set 9 | gouyave
# Processing Record 38 of Set 9 | northam
# Processing Record 39 of Set 9 | te anau
# Processing Record 40 of Set 9 | puerto del rosario
# Processing Record 41 of Set 9 | fare
# Processing Record 42 of Set 9 | rocky mountain house
# Processing Record 43 of Set 9 | presidencia roque saenz pena
# Processing Record 44 of Set 9 | sao felix do xingu
# Processing Record 45 of Set 9 | zeya
# Processing Record 46 of Set 9 | high level
# Processing Record 47 of Set 9 | port blair
# Processing Record 48 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 9 | kavaratti
# Processing Record 50 of Set 9 | bony
# Processing Record 1 of Set 10 | okato
# Processing Record 2 of Set 10 | broken hill
# Processing Record 3 of Set 10 | siyabuswa
# Processing Record 4 of Set 10 | avera
# Processing Record 5 of Set 10 | salou
# Processing Record 6 of Set 10 | sao miguel do araguaia
# Processing Record 7 of Set 10 | ossora
# Processing Record 8 of Set 10 | kungurtug
# Processing Record 9 of Set 10 | san juan
# Processing Record 10 of Set 10 | heihe
# Processing Record 11 of Set 10 | camana
# Processing Record 12 of Set 10 | batticaloa
# Processing Record 13 of Set 10 | semnan
# Processing Record 14 of Set 10 | ancud
# Processing Record 15 of Set 10 | durango
# Processing Record 16 of Set 10 | nanakuli
# Processing Record 17 of Set 10 | vestmanna
# Processing Record 18 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 10 | san carlos del zulia
# Processing Record 20 of Set 10 | ntungamo
# Processing Record 21 of Set 10 | madimba
# Processing Record 22 of Set 10 | samarai
# Processing Record 23 of Set 10 | shitkino
# Processing Record 24 of Set 10 | tura
# Processing Record 25 of Set 10 | kapoeta
# Processing Record 26 of Set 10 | mantua
# Processing Record 27 of Set 10 | okhotsk
# Processing Record 28 of Set 10 | zarichne
# Processing Record 29 of Set 10 | ahuimanu
# Processing Record 30 of Set 10 | motril
# Processing Record 31 of Set 10 | san diego de la union
# Processing Record 32 of Set 10 | kalmunai
# Processing Record 33 of Set 10 | peniche
# Processing Record 34 of Set 10 | tuatapere
# Processing Record 35 of Set 10 | birin
# Processing Record 36 of Set 10 | santa cruz
# Processing Record 37 of Set 10 | makakilo city
# Processing Record 38 of Set 10 | tabuk
# Processing Record 39 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 10 | sucua
# Processing Record 41 of Set 10 | bambous virieux
# Processing Record 42 of Set 10 | iskateley
# Processing Record 43 of Set 10 | inzer
# Processing Record 44 of Set 10 | gat
# Processing Record 45 of Set 10 | elat
# Processing Record 46 of Set 10 | plettenberg bay
# Processing Record 47 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 48 of Set 10 | saint-prosper
# Processing Record 49 of Set 10 | morros
# Processing Record 50 of Set 10 | guisa
# Processing Record 1 of Set 11 | ugoofaaru
# Processing Record 2 of Set 11 | mokhsogollokh
# Processing Record 3 of Set 11 | bontang
# Processing Record 4 of Set 11 | tommot
# Processing Record 5 of Set 11 | diamantino
# Processing Record 6 of Set 11 | quatre cocos
# Processing Record 7 of Set 11 | alta floresta
# Processing Record 8 of Set 11 | dublin
# Processing Record 9 of Set 11 | qafsah
# City not found. Skipping...
# Processing Record 10 of Set 11 | lorengau
# Processing Record 11 of Set 11 | segou
# Processing Record 12 of Set 11 | charlottesville
# Processing Record 13 of Set 11 | nalut
# Processing Record 14 of Set 11 | bay roberts
# Processing Record 15 of Set 11 | auch
# Processing Record 16 of Set 11 | cururupu
# Processing Record 17 of Set 11 | itarema
# Processing Record 18 of Set 11 | khasan
# Processing Record 19 of Set 11 | bilibino
# Processing Record 20 of Set 11 | krasnokamensk
# Processing Record 21 of Set 11 | sault sainte marie
# Processing Record 22 of Set 11 | mana
# Processing Record 23 of Set 11 | mayo
# Processing Record 24 of Set 11 | strezhevoy
# Processing Record 25 of Set 11 | senanga
# Processing Record 26 of Set 11 | korla
# Processing Record 27 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 28 of Set 11 | bolu
# Processing Record 29 of Set 11 | mitu
# Processing Record 30 of Set 11 | vangaindrano
# Processing Record 31 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 32 of Set 11 | motygino
# Processing Record 33 of Set 11 | nichinan
# Processing Record 34 of Set 11 | shar
# Processing Record 35 of Set 11 | bilma
# Processing Record 36 of Set 11 | kroya
# Processing Record 37 of Set 11 | ayagoz
# Processing Record 38 of Set 11 | jiangkou
# Processing Record 39 of Set 11 | abu samrah
# Processing Record 40 of Set 11 | dibaya
# City not found. Skipping...
# Processing Record 41 of Set 11 | constitucion
# Processing Record 42 of Set 11 | palmar
# Processing Record 43 of Set 11 | yabelo
# Processing Record 44 of Set 11 | ixtapa
# Processing Record 45 of Set 11 | cranbrook
# Processing Record 46 of Set 11 | tupik
# Processing Record 47 of Set 11 | malindi
# Processing Record 48 of Set 11 | san jose
# Processing Record 49 of Set 11 | itoman
# Processing Record 50 of Set 11 | bhitarwar
# Processing Record 1 of Set 12 | dali
# Processing Record 2 of Set 12 | ambilobe
# Processing Record 3 of Set 12 | parnamirim
# Processing Record 4 of Set 12 | sioux lookout
# Processing Record 5 of Set 12 | nanortalik
# Processing Record 6 of Set 12 | yulara
# Processing Record 7 of Set 12 | porto santo
# Processing Record 8 of Set 12 | atchison
# Processing Record 9 of Set 12 | ust-maya
# Processing Record 10 of Set 12 | bonavista
# Processing Record 11 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 12 of Set 12 | bure
# Processing Record 13 of Set 12 | zhangye
# Processing Record 14 of Set 12 | calategas
# City not found. Skipping...
# Processing Record 15 of Set 12 | labuan
# Processing Record 16 of Set 12 | khandyga
# Processing Record 17 of Set 12 | dabou
# Processing Record 18 of Set 12 | rabo de peixe
# Processing Record 19 of Set 12 | sakakah
# Processing Record 20 of Set 12 | kirkland lake
# Processing Record 21 of Set 12 | taltal
# Processing Record 22 of Set 12 | meadow lake
# Processing Record 23 of Set 12 | chachapoyas
# Processing Record 24 of Set 12 | bac lieu
# Processing Record 25 of Set 12 | male
# Processing Record 26 of Set 12 | falam
# Processing Record 27 of Set 12 | richards bay
# Processing Record 28 of Set 12 | tacoronte
# Processing Record 29 of Set 12 | saint-georges
# Processing Record 30 of Set 12 | monatele
# City not found. Skipping...
# Processing Record 31 of Set 12 | oksfjord
# Processing Record 32 of Set 12 | huarmey
# Processing Record 33 of Set 12 | tyukhtet
# Processing Record 34 of Set 12 | aksay
# Processing Record 35 of Set 12 | liwale
# Processing Record 36 of Set 12 | darapidap
# Processing Record 37 of Set 12 | andros town
# Processing Record 38 of Set 12 | poum
# Processing Record 39 of Set 12 | vadso
# Processing Record 40 of Set 12 | tete
# Processing Record 41 of Set 12 | ust-nera
# Processing Record 42 of Set 12 | macusani
# Processing Record 43 of Set 12 | dunda
# Processing Record 44 of Set 12 | nabire
# Processing Record 45 of Set 12 | la paz
# Processing Record 46 of Set 12 | mazagao
# Processing Record 47 of Set 12 | inuvik
# Processing Record 48 of Set 12 | daru
# Processing Record 49 of Set 12 | havoysund
# Processing Record 50 of Set 12 | ust-kuyga
# Processing Record 1 of Set 13 | abadan
# Processing Record 2 of Set 13 | piacabucu
# Processing Record 3 of Set 13 | klyuchevskiy
# Processing Record 4 of Set 13 | gidam
# Processing Record 5 of Set 13 | venado tuerto
# Processing Record 6 of Set 13 | hauterive
# Processing Record 7 of Set 13 | leh
# Processing Record 8 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 9 of Set 13 | farafangana
# Processing Record 10 of Set 13 | moerai
# Processing Record 11 of Set 13 | pocone
# Processing Record 12 of Set 13 | aksu
# Processing Record 13 of Set 13 | solok
# Processing Record 14 of Set 13 | starkville
# Processing Record 15 of Set 13 | alekseyevskoye
# Processing Record 16 of Set 13 | moree
# Processing Record 17 of Set 13 | balikpapan
# Processing Record 18 of Set 13 | mossendjo
# Processing Record 19 of Set 13 | san jeronimo
# Processing Record 20 of Set 13 | krasnoselkup
# Processing Record 21 of Set 13 | puerto narino
# Processing Record 22 of Set 13 | tucuma
# Processing Record 23 of Set 13 | svetlogorsk
# Processing Record 24 of Set 13 | thurso
# Processing Record 25 of Set 13 | caxito
# Processing Record 26 of Set 13 | bud
# Processing Record 27 of Set 13 | berdigestyakh
# Processing Record 28 of Set 13 | baiyin
# Processing Record 29 of Set 13 | half moon bay
# Processing Record 30 of Set 13 | kieta
# Processing Record 31 of Set 13 | cordoba
# Processing Record 32 of Set 13 | maragogi
# Processing Record 33 of Set 13 | muros
# Processing Record 34 of Set 13 | dire
# Processing Record 35 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 36 of Set 13 | giyani
# Processing Record 37 of Set 13 | bayan
# Processing Record 38 of Set 13 | orangeville
# Processing Record 39 of Set 13 | arica
# Processing Record 40 of Set 13 | bairiki
# Processing Record 41 of Set 13 | narasannapeta
# Processing Record 42 of Set 13 | tevaitoa
# Processing Record 43 of Set 13 | acajutla
# Processing Record 44 of Set 13 | cassilandia
# Processing Record 45 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 46 of Set 13 | yekaterinovka
# Processing Record 47 of Set 13 | kalabo
# Processing Record 48 of Set 13 | buraydah
# Processing Record 49 of Set 13 | watertown
# Processing Record 50 of Set 13 | niquelandia
# Processing Record 1 of Set 14 | cam ranh
# Processing Record 2 of Set 14 | grindavik
# Processing Record 3 of Set 14 | rawatsar
# Processing Record 4 of Set 14 | osoyoos
# Processing Record 5 of Set 14 | nzerekore
# Processing Record 6 of Set 14 | hammerfest
# Processing Record 7 of Set 14 | capao da canoa
# Processing Record 8 of Set 14 | panlaitan
# Processing Record 9 of Set 14 | serov
# Processing Record 10 of Set 14 | kyra
# Processing Record 11 of Set 14 | kutum
# Processing Record 12 of Set 14 | collie
# Processing Record 13 of Set 14 | nioro
# Processing Record 14 of Set 14 | akdepe
# Processing Record 15 of Set 14 | kure
# Processing Record 16 of Set 14 | point pleasant
# Processing Record 17 of Set 14 | maldonado
# Processing Record 18 of Set 14 | killybegs
# Processing Record 19 of Set 14 | marsabit
# Processing Record 20 of Set 14 | turayf
# Processing Record 21 of Set 14 | bumba
# Processing Record 22 of Set 14 | norsup
# Processing Record 23 of Set 14 | lakatoro
# Processing Record 24 of Set 14 | yakeshi
# Processing Record 25 of Set 14 | nicoya
# Processing Record 26 of Set 14 | pokhara
# Processing Record 27 of Set 14 | bone
# Processing Record 28 of Set 14 | le port
# Processing Record 29 of Set 14 | shalinskoye
# Processing Record 30 of Set 14 | puri
# Processing Record 31 of Set 14 | jardim
# Processing Record 32 of Set 14 | odweyne
# Processing Record 33 of Set 14 | lazurne
# Processing Record 34 of Set 14 | port-gentil
# Processing Record 35 of Set 14 | lamar
# Processing Record 36 of Set 14 | north battleford
# Processing Record 37 of Set 14 | macapa
# Processing Record 38 of Set 14 | forbes
# Processing Record 39 of Set 14 | lakhdenpokhya
# Processing Record 40 of Set 14 | shizunai
# Processing Record 41 of Set 14 | ambanja
# Processing Record 42 of Set 14 | kristiinankaupunki
# Processing Record 43 of Set 14 | ubinskoye
# Processing Record 44 of Set 14 | aranos
# Processing Record 45 of Set 14 | bani walid
# Processing Record 46 of Set 14 | tautira
# Processing Record 47 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 48 of Set 14 | husavik
# Processing Record 49 of Set 14 | thika
# Processing Record 50 of Set 14 | kuytun
# Processing Record 1 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 15 | port lincoln
# Processing Record 3 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 15 | cayeli
# Processing Record 5 of Set 15 | truth or consequences
# Processing Record 6 of Set 15 | nantucket
# Processing Record 7 of Set 15 | kashi
# Processing Record 8 of Set 15 | zahirabad
# Processing Record 9 of Set 15 | turukhansk
# Processing Record 10 of Set 15 | jiroft
# City not found. Skipping...
# Processing Record 11 of Set 15 | aykhal
# Processing Record 12 of Set 15 | mazarron
# Processing Record 13 of Set 15 | mehamn
# Processing Record 14 of Set 15 | omsukchan
# Processing Record 15 of Set 15 | balud
# Processing Record 16 of Set 15 | hay river
# Processing Record 17 of Set 15 | faya
# Processing Record 18 of Set 15 | salalah
# Processing Record 19 of Set 15 | nelson bay
# Processing Record 20 of Set 15 | zerbst
# Processing Record 21 of Set 15 | dolzhanskaya
# Processing Record 22 of Set 15 | hede
# Processing Record 23 of Set 15 | valverde del camino
# Processing Record 24 of Set 15 | paamiut
# Processing Record 25 of Set 15 | ixcaquixtla
# City not found. Skipping...
# Processing Record 26 of Set 15 | gazanjyk
# Processing Record 27 of Set 15 | sinnamary
# Processing Record 28 of Set 15 | jalu
# Processing Record 29 of Set 15 | zhezkazgan
# Processing Record 30 of Set 15 | nianzishan
# Processing Record 31 of Set 15 | tocopilla
# Processing Record 32 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 33 of Set 15 | fomboni
# Processing Record 34 of Set 15 | santa lucia
# Processing Record 35 of Set 15 | hambantota
# Processing Record 36 of Set 15 | vuktyl
# Processing Record 37 of Set 15 | pangkalanbuun
# Processing Record 38 of Set 15 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 39 of Set 15 | sao miguel do tapuio
# Processing Record 40 of Set 15 | bada
# Processing Record 41 of Set 15 | walvis bay
# Processing Record 42 of Set 15 | marawi
# Processing Record 43 of Set 15 | bundaberg
# Processing Record 44 of Set 15 | senador jose porfirio
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Punta Arenas      CL -53.1500  -70.9167     57.31        47
# 1              Hermanus      ZA -34.4187   19.2345     76.89        79
# 2            Dawlatabad      AF  36.4141   64.9053     46.31        61
# 3              Novikovo      RU  51.1537   37.8879     27.45        95
# 4             Esperance      AU -33.8667  121.9000     65.10        73
# 5               Kahului      US  20.8947 -156.4700     72.84        83
# 6              Thompson      CA  55.7435  -97.8558    -12.30        95
# 7  Vila Franca Do Campo      PT  37.7167  -25.4333     61.21        66
# 8             Upernavik      GL  72.7868  -56.1549     -4.68        98
# 9                Tiarei      PF -17.5333 -149.3333     75.22        76
#
#    Cloudiness  Wind Speed Current Description
# 0          40       36.82    scattered clouds
# 1          94       10.13     overcast clouds
# 2         100        8.68     overcast clouds
# 3          84        8.52       broken clouds
# 4          99       14.99     overcast clouds
# 5           0        7.00           clear sky
# 6         100        6.04     overcast clouds
# 7          96       11.21     overcast clouds
# 8         100       13.62          light snow
# 9          99       12.21          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
